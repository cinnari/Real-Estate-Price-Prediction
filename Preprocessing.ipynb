# %%
# Importing the necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset
filepath = 'real_estate_data.csv'  # Specify the correct file path
data = pd.read_csv(filepath)

# %%
# Display the first few rows of the data
data.head(10)
# Out:
#                                         Full Address  \
# 0            30188 Johnson Green\nBuckland, WV 59978
# 1    589 Shannon Squares\nEast Kristenland, AK 16494
# 2            24228 Julia Forge\nWest Jerry, ME 05645
# 3                 377 Megan Way\nShawnfurt, ND 51619
# 4       221 Carr Extensions\nJarvisborough, UT 82903
# 5  156 Christopher Shore Suite 255\nPort Jeremy, ...
# 6         41933 Glenn Forges\nMcdanieltown, HI 82405
# 7     74615 Green Inlet\nSouth Travismouth, OH 85875
# 8                   Unit 5876 Box 2263\nDPO AA 79389
# 9     56337 Alvarado Street\nPort Danielle, OK 84504
#
#                  Project Name Primary Photo            First Two Photos  \
# 0             Richardson-Reid   theory.jpeg        short.jpg,decide.png
# 1                    Good Inc     trial.jpg         later.jpeg,pass.jpg
# 2                Reynolds PLC     check.bmp   outside.jpg,scientist.bmp
# 3                  Diaz-Owens      lead.gif      available.jpg,seat.bmp
# ...

# %%
# Display summary statistics of the dataset
data.describe()
# Out:
#        Asking Price (PHP)  Rent Price (PHP)  Price per Sqm (PHP)  \
# count        1.012000e+03        988.000000          2000.000000
# mean         2.021813e+07      56510.016194        124601.245000
# std          1.282985e+07      25007.599450         42779.138786
# min          1.067440e+06      15155.000000         50012.000000
# 25%          9.738329e+06      33914.250000         87360.250000
# 50%          1.809309e+07      55638.000000        124403.000000
# 75%          2.912402e+07      77803.750000        160445.750000
# max          5.832106e+07      99847.000000        199982.000000
#
#        Down payment Php  Down payment %  Advanced Payment (months)  \
# count      1.012000e+03          1012.0                 988.000000
# mean       4.043625e+06            20.0                   2.038462
# std        2.565970e+06             0.0                   0.811854
# min        2.134880e+05            20.0                   1.000000
# ...

# %%
# Check for missing values
missing_data = data.isnull().sum()
print("Missing values in each column:\n", missing_data)

# # Option 1: Drop rows with missing values
# data_cleaned = data.dropna()

# # Option 2: Fill missing values with the median of each column
# # data_cleaned = data.fillna(data.median())

# # Option 3: Fill missing categorical data with the most frequent value (mode)
# # data_cleaned['column_name'] = data_cleaned['column_name'].fillna(data_cleaned['column_name'].mode()[0])

# # Display cleaned data
# data_cleaned.head()
# Out:
# Missing values in each column:
#  Full Address                              0
# Project Name                              0
# Primary Photo                             0
# First Two Photos                          0
# Floor Plan                                0
# Property Type                             0
# For Sale or For Rent                      0
# Asking Price (PHP)                      988
# Rent Price (PHP)                       1012
# Price per Sqm (PHP)                       0
# Down payment Php                        988
# Down payment %                          988
# Advanced Payment (months)              1012
# Security Deposit (months)              1012
# Minimum Rent duration (months)         1012
# Generic Address                           0
# Approximated GPS Pin                      0
# Size (sqm)                                0
# Property Specifications                   0
# Property Features                         0
# Property Category                         0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 35 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Full Address                         2000 non-null   object
#  1   Project Name                         2000 non-null   object
#  2   Primary Photo                        2000 non-null   object
#  3   First Two Photos                     2000 non-null   object
#  4   Floor Plan                           2000 non-null   object
#  5   Property Type                        2000 non-null   object
#  6   For Sale or For Rent                 2000 non-null   object
#  7   Asking Price (PHP)                   1012 non-null   float64
#  8   Rent Price (PHP)                     988 non-null    float64
#  9   Price per Sqm (PHP)                  2000 non-null   int64
#  10  Down payment Php                     1012 non-null   float64
# ...
